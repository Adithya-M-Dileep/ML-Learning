# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
img=cv2.imread("images4.jfif")

img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img_copy=img.copy()
plt.imshow(img)

lower=np.array([50,0,0])
higher=np.array([255,50,50])


mask=cv2.inRange(img,lower,higher)

plt.imshow(mask,"gray")
plt.show()

cont,_=cv2.findContours(mask,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)

plt.imshow(cont_img)
plt.show()

cont_img=cv2.drawContours(img,cont,-1,255,3)



c=max(cont,key=cv2.contourArea)

x,y,w,h=cv2.boundingRect(c)


rect_img=cv2.rectangle(img_copy,(x,y),(x+w,y+h),(0,255,0),2)

plt.imshow(rect_img)
plt.show()

cropped_img=img_copy[y:y+h,x:x+w]

plt.imshow(cropped_img)
plt.show()
